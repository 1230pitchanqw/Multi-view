# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
MAE = [1.122, 1.174, 1.107, 1.053]
RMSE = [1.677, 1.668, 1.670, 1.596]
PCC = [0.486, 0.489, 0.518, 0.552]
R2 = [0.228, 0.237, 0.235, 0.301]

# %%
MAE_std = [0.020, 0.009, 0.040, 0.018]
RMSE_std = [0.018,0.020,0.025,0.016]
PCC_std = [0.005,0.005,0.005,0.006]
R2_std = [0.005,0.005,0.011,0.008]

# %%
cor_dict = {0:"r", 1:"orange", 2:"g", 3:"b"}
label_dict = {0:"demograpic", 1:"medical codes", 2:"facility usuage", 3:"All"}

fig = plt.figure()
#fig.set_size_inches(20, 4)

ax1 = fig.add_subplot(111)
for j in range(4):
    ax1.bar(j, MAE[j], yerr=MAE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(1, 1.2)
ax1.set_xlabel("RSME"+" "*60+"MAE")
ax1.set_ylabel("RSME score")
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, RMSE[j], yerr=RMSE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(1.55, 1.7)
ax2.set_ylabel("MAE score")
plt.legend(loc='lower left')
plt.savefig("Fig4",dpi=300)
plt.show()

# %%
cor_dict = {0:"r", 1:"orange", 2:"g", 3:"b"}
label_dict = {0:"demograpic", 1:"medical codes", 2:"facility usuage", 3:"All"}

fig = plt.figure()
#fig.set_size_inches(20, 4)

ax1 = fig.add_subplot(111)
for j in range(4):
    ax1.bar(j, PCC[j], yerr=PCC_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(0.4, 0.58)
ax1.set_xlabel("PCC"+" "*60+"R-square")
ax1.set_ylabel("PCC score")
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, R2[j], yerr=R2_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(0.2,0.33)
ax2.set_ylabel("R-square score")
plt.legend(loc='lower left')
plt.savefig("Fig41",dpi=300)
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(21, 8)

ax1 = fig.add_subplot(1,2,1)
for j in range(4):
    ax1.bar(j, MAE[j], yerr=MAE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(1, 1.2)
ax1.set_xlabel("RSME"+" "*45+"MAE", fontsize=18)
ax1.set_ylabel("RSME score", fontsize=18)
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, RMSE[j], yerr=RMSE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(1.55, 1.7)
ax2.set_ylabel("MAE score", fontsize=18)
plt.legend(loc='lower left', fontsize=12)




ax1 = fig.add_subplot(1,2.2,2)
for j in range(4):
    ax1.bar(j, PCC[j], yerr=PCC_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(0.4, 0.58)
ax1.set_xlabel("PCC"+" "*45+"R-square", fontsize=18)
ax1.set_ylabel("PCC score", fontsize=18)
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, R2[j], yerr=R2_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(0.2,0.33)
ax2.set_ylabel("R-square score", fontsize=18)
plt.legend(loc='lower left', fontsize=12)
plt.savefig("Fig4",dpi=300)

plt.show()

# %%
MAE = [0.210, 0.196, 0.194, 0.183]
RMSE = [0.246, 0.235, 0.237, 0.224]
PCC = [0.580, 0.610, 0.574, 0.637]
R2 = [0.278, 0.343, 0.329, 0.400]

# %%
MAE_std = [0.006, 0.005, 0.002, 0.001]
RMSE_std = [0.005,0.004,0.002,0.001]
PCC_std = [0.008,0.005,0.008,0.002]
R2_std = [0.031,0.022,0.008,0.002]

# %%
cor_dict = {0:"r", 1:"orange", 2:"g", 3:"b"}
label_dict = {0:"demograpic", 1:"medical codes", 2:"facility usuage", 3:"All"}

fig = plt.figure()
#fig.set_size_inches(20, 4)

ax1 = fig.add_subplot(111)
for j in range(4):
    ax1.bar(j, MAE[j], yerr=MAE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(0.15, 0.22)
ax1.set_xlabel("RSME"+" "*60+"MAE")
ax1.set_ylabel("RSME score")
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, RMSE[j], yerr=RMSE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(0.21, 0.26)
ax2.set_ylabel("MAE score")
plt.legend(loc='lower left')
plt.savefig("Fig5",dpi=300)

plt.show()

# %%
cor_dict = {0:"r", 1:"orange", 2:"g", 3:"b"}
label_dict = {0:"demograpic", 1:"medical codes", 2:"facility usuage", 3:"All"}

fig = plt.figure()
#fig.set_size_inches(20, 4)

ax1 = fig.add_subplot(111)
for j in range(4):
    ax1.bar(j, PCC[j], yerr=PCC_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(0.5, 0.65)
ax1.set_xlabel("PCC"+" "*60+"R-square")
ax1.set_ylabel("PCC score")
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, R2[j], yerr=R2_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(0.25,0.41)
ax2.set_ylabel("R-square score")
plt.legend(loc='lower left')
plt.savefig("Fig51",dpi=300)

plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(21, 8)

ax1 = fig.add_subplot(1,2,1)
for j in range(4):
    ax1.bar(j, MAE[j], yerr=MAE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(0.15, 0.22)
ax1.set_xlabel("RSME"+" "*45+"MAE", fontsize=18)
ax1.set_ylabel("RSME score", fontsize=18)
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, RMSE[j], yerr=RMSE_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(0.21, 0.26)
ax2.set_ylabel("MAE score", fontsize=18)
plt.legend(loc='lower left', fontsize=12)


ax1 = fig.add_subplot(122)
for j in range(4):
    ax1.bar(j, PCC[j], yerr=PCC_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax1.set_ylim(0.5, 0.65)
ax1.set_xlabel("PCC"+" "*45+"R-square", fontsize=18)
ax1.set_ylabel("PCC score", fontsize=18)
ax1.set_xticks([])

ax2 = ax1.twinx()

for j in range(4):
    ax2.bar(j+6, R2[j], yerr=R2_std[j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label_dict[j])

ax2.set_ylim(0.25,0.41)
ax2.set_ylabel("R-square score", fontsize=18)
plt.legend(loc='lower left', fontsize=12)
plt.savefig("Fig5",dpi=300)

plt.show()

# %%
Top1 = [6061, 6587, 6807]
Top3 = [7075, 8119, 8683]
Top5 = [10294, 11108, 15432]

Top_list = Top1+Top3+Top5

# %%
label = ["Lasso", "GBM", "Multi-view"]

fig = plt.figure()
# fig.set_size_inches(15, 4)
ax1 = fig.add_subplot(111)

for i in range(3):
    for j in range(3):
        if i==0:
            ax1.bar(i*4+j, Top_list[i*3+j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6, label=label[j])
        else:
            ax1.bar(i*4+j, Top_list[i*3+j], width=0.8, bottom=0.0, align='center', color=cor_dict[j], alpha=0.6)

ax1.set_ylim(0, 16000)
ax1.set_xlabel("Top1"+" "*30+"Top3"+" "*30+"Top5")
ax1.set_ylabel("Mean cost ($)")
ax1.set_xticks([])
plt.legend(loc='lower left', fontsize=12)
plt.show()

# %%
Diff_lasso = [816377, 1055149, 1120217]
Diff_gbm = [240570, 369680, 942787]

# %%
label = ["Lasso-Diff", "GBM-Diff"]

plt.plot(Diff_lasso, "*-", markersize=12)
plt.plot(Diff_gbm, "*-", markersize=12)
plt.ylabel("Potential influence in cost ($)")
plt.xticks(range(3), ["Top1", "Top3", "Top5"])
plt.ylim(0, 1200000)

plt.show()
